# %% [markdown]
# <div align="center">
#
# #### Lab 3
#
# # National Tsing Hua University
#
# #### Spring 2024
#
# #### 11220IEEM 513600
#
# #### Deep Learning and Industrial Applications
#
# ## Lab 3: Anomaly Detection in Industrial Applications
#
# </div>

# %% [markdown]
# ### Introduction
#
# In today's industrial landscape, the ability to detect anomalies in manufacturing processes and products is critical for maintaining quality, efficiency, and safety. This lab focuses on leveraging deep learning techniques for anomaly detection in various industrial applications, using the MVTEC Anomaly Detection Dataset. By employing ImageNet-pretrained models available in torchvision, students will gain hands-on experience in classfying defects and irregularities across different types of industrial products.
#
# Throughout this lab, you'll be involved in the following key activities:
# - Explore and process the MVTec Anomaly Detection Dataset.
# - Apply ImageNet-pretrained models from [Torchvision](https://pytorch.org/vision/stable/models.html) to detect anomalies in industrial products.
# - Evaluate the performance of the models to understand their effectiveness in real-world industrial applications.
#
# ### Objectives
#
# - Understand the principles of anomaly detection in the context of industrial applications.
# - Learn how to implement and utilize ImageNet-pretrained models for detecting anomalies.
# - Analyze and interpret the results of the anomaly detection models to assess their practicality in industrial settings.
#
# ### Dataset
#
# The MVTec AD Dataset is a comprehensive collection of high-resolution images across different categories of industrial products, such as bottles, cables, and metal nuts, each with various types of defects. This dataset is pivotal for developing and benchmarking anomaly detection algorithms. You can download our lab's dataset [here](https://drive.google.com/file/d/19600hUOpx0hl78TdpdH0oyy-gGTk_F_o/view?usp=share_link). You can drop downloaded data and drop to colab, or you can put into yor google drive.
#
# ### References
# - [MVTec AD Dataset](https://www.kaggle.com/datasets/ipythonx/mvtec-ad/data) for the dataset used in this lab.
# - [Torchvision Models](https://pytorch.org/vision/stable/models.html) for accessing ImageNet-pretrained models to be used in anomaly detection tasks.
# - [State-of-the-Art Anomaly Detection on MVTec AD](https://paperswithcode.com/sota/anomaly-detection-on-mvtec-ad) for insights into the latest benchmarks and methodologies in anomaly detection applied to the MVTec AD dataset.
# - [CVPR 2019: MVTec AD — A Comprehensive Real-World Dataset for Unsupervised Anomaly Detection] for the original paper of MVTec AD dataset.

# %%
import glob
import matplotlib.pyplot as plt
import random
from tqdm.auto import tqdm
import cv2
import numpy as np

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !tar -xvf drive/MyDrive/113_deep_learning/lab3/tile.tar.gz tile

# %%
file_paths = glob.glob('tile/*/*.png')
file_paths = sorted([path for path in file_paths if path.split('/')[-1] in [f'{i:03}.png' for i in range(15)]])

# %%
all_data = []

for img in tqdm(file_paths):
    img = cv2.imread(img)
    img = img[..., ::-1]
    all_data.append(img)

all_data = np.stack(all_data)
print(all_data.shape)
# Out:
#   0%|          | 0/90 [00:00<?, ?it/s]
# (90, 840, 840, 3)

# %%
import matplotlib.pyplot as plt
import numpy as np

classes = sorted(set([path.split('/')[1] for path in file_paths]))
print(f'Classes: {classes}')

images_per_class = len(all_data) // len(classes)
fig, axs = plt.subplots(len(classes), 2, figsize=(6, 4 * len(classes)))

for i, class_name in enumerate(classes):
    index = i * images_per_class
    for j in range(2):
        axs[i, j].set_title(f'{i}. {class_name}')
        axs[i, j].imshow(all_data[index + j])
        axs[i, j].axis('off')

plt.tight_layout()
plt.show()
# Out:
# Classes: ['crack', 'glue_strip', 'good', 'gray_stroke', 'oil', 'rough']

# %% [markdown]
# ## A. Data Loading and Preprocessing

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset, random_split
import numpy as np

num_classes = 6
images_per_class = 15
train_images_per_class = int(images_per_class * 0.8)
val_images_per_class = int(images_per_class * 0.2)

x_train = []
x_val = []

for i in range(num_classes):
    start_index = i * images_per_class
    x_train.extend(all_data[start_index:start_index + train_images_per_class])
    x_val.extend(all_data[start_index + train_images_per_class:start_index + images_per_class])

# The shape changes from (batch_size, height, width, channels) to (batch_size, channels, height, width)
x_train = np.transpose(np.array(x_train), (0, 3, 1, 2))
x_val = np.transpose(np.array(x_val), (0, 3, 1, 2))

y_train = np.concatenate([np.full(train_images_per_class, i) for i in range(num_classes)])
y_val = np.concatenate([np.full(val_images_per_class, i) for i in range(num_classes)])

print(f'Shape of x_train: {x_train.shape}')
print(f'Shape of x_val: {x_val.shape}')
print(f'Shape of y_train: {y_train.shape}')
print(f'Shape of y_val: {y_val.shape}')
# Out:
# Shape of x_train: (72, 3, 840, 840)
# Shape of x_val: (18, 3, 840, 840)
# Shape of y_train: (72,)
# Shape of y_val: (18,)

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image

train_transforms = transforms.Compose(
    [
        transforms.Resize((32, 32)),
        transforms.AutoAugment(),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
    ]
)

val_transforms = transforms.Compose(
    [
        transforms.Resize((32, 32)),
        transforms.ToTensor(),
    ]
)

class MyDataset(Dataset):
    def __init__(self, x, y, transform=None):
        self.x = x
        self.y = torch.from_numpy(y).long()
        self.transform = transform

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        new_x = np.transpose(self.x[idx], (1, 2, 0))
        return self.transform(Image.fromarray(new_x)), self.y[idx]

# %%
batch_size = 16 # 32 8 16

train_dataset = MyDataset(x_train, y_train, train_transforms)
val_dataset = MyDataset(x_val, y_val, val_transforms)

train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, num_workers=2, pin_memory=True, persistent_workers=True)
val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False, num_workers=1, pin_memory=True, persistent_workers=True)

# %% [markdown]
# ## B. Defining Neural Networks

# %%
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models

#model = models.resnet18(weights='IMAGENET1K_V1')
model = models.resnet50(weights='IMAGENET1K_V1') # resnet152 IMAGENET1K_V2

# ConvNet as fixed feature extractor (freeze parameters)
for param in model.parameters():
    param.requires_grad = False

num_ftrs = model.fc.in_features
num_class = 6

# change # of class from 1000 into 8 in the last layer
model.fc = nn.Linear(num_ftrs, num_class)
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=6, bias=True)
# )

# %% [markdown]
# ## C. Training the Neural Network

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR, StepLR
from tqdm.auto import tqdm

train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

epochs = 150 # 100
model = model.cuda()

best_val_loss = float('inf')
best_val_acc = -1

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=5e-4) # 1e-3 Adam 5e-4
lr_scheduler = CosineAnnealingLR(optimizer, T_max=len(train_loader)*epochs, eta_min=0)

for epoch in tqdm(range(epochs)):
    # Training
    model.train()
    total_loss = 0.0
    train_correct = 0
    total_train_samples = 0

    for images, labels in train_loader:
        images = images.cuda()
        images = (images) / 255.
        labels = labels.cuda()
        optimizer.zero_grad()
        outputs = model(images)

        labels = labels.long()

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

        train_predicted = outputs.argmax(-1)
        train_correct += (train_predicted == labels).sum().item()
        total_train_samples += labels.size(0)

    avg_train_loss = total_loss / len(train_loader)
    train_accuracy = 100. * train_correct / total_train_samples

    # Validation
    model.eval()
    total_val_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in val_loader:
            images = images.cuda()
            images = (images) / 255.
            labels = labels.cuda()
            outputs = model(images)

            labels = labels.long()

            loss = criterion(outputs, labels)
            total_val_loss += loss.item()

            predicted = outputs.argmax(-1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    avg_val_loss = total_val_loss / len(val_loader)
    val_accuracy = 100. * correct / total

    # Learning rate update
    lr_scheduler.step()

    # Checkpoint
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss

    if val_accuracy > best_val_acc:
        best_val_acc = val_accuracy
        torch.save(model.state_dict(), 'model_classification.pth')

    print(f'Epoch {epoch+1}/{epochs}, Train loss: {avg_train_loss:.4f}, Train acc: {train_accuracy:.4f}%, Val loss: {avg_val_loss:.4f}, Val acc: {val_accuracy:.4f}%, Best Val loss: {best_val_loss:.4f} Best Val acc: {best_val_acc:.2f}%')

    # Store performance
    train_losses.append(avg_train_loss)
    train_accuracies.append(train_accuracy)
    val_losses.append(avg_val_loss)
    val_accuracies.append(val_accuracy)
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]
# Epoch 1/150, Train loss: 1.9125, Train acc: 12.5000%, Val loss: 2.1238, Val acc: 16.6667%, Best Val loss: 2.1238 Best Val acc: 16.67%
# Epoch 2/150, Train loss: 1.8317, Train acc: 18.0556%, Val loss: 1.8000, Val acc: 16.6667%, Best Val loss: 1.8000 Best Val acc: 16.67%
# Epoch 3/150, Train loss: 1.8676, Train acc: 13.8889%, Val loss: 3.3337, Val acc: 16.6667%, Best Val loss: 1.8000 Best Val acc: 16.67%
# Epoch 4/150, Train loss: 1.7344, Train acc: 33.3333%, Val loss: 5.3396, Val acc: 16.6667%, Best Val loss: 1.8000 Best Val acc: 16.67%
# Epoch 5/150, Train loss: 1.7040, Train acc: 38.8889%, Val loss: 9.0438, Val acc: 16.6667%, Best Val loss: 1.8000 Best Val acc: 16.67%
# Epoch 6/150, Train loss: 1.7357, Train acc: 22.2222%, Val loss: 6.9057, Val acc: 16.6667%, Best Val loss: 1.8000 Best Val acc: 16.67%
# Epoch 7/150, Train loss: 1.6944, Train acc: 23.6111%, Val loss: 7.8901, Val acc: 16.6667%, Best Val loss: 1.8000 Best Val acc: 16.67%
# Epoch 8/150, Train loss: 1.7530, Train acc: 23.6111%, Val loss: 7.0791, Val acc: 16.6667%, Best Val loss: 1.8000 Best Val acc: 16.67%
# Epoch 9/150, Train loss: 1.5946, Train acc: 40.2778%, Val loss: 4.3255, Val acc: 16.6667%, Best Val loss: 1.8000 Best Val acc: 16.67%
# Epoch 10/150, Train loss: 1.6107, Train acc: 33.3333%, Val loss: 11.8385, Val acc: 16.6667%, Best Val loss: 1.8000 Best Val acc: 16.67%
# Epoch 11/150, Train loss: 1.6093, Train acc: 34.7222%, Val loss: 14.3864, Val acc: 16.6667%, Best Val loss: 1.8000 Best Val acc: 16.67%
# Epoch 12/150, Train loss: 1.6350, Train acc: 36.1111%, Val loss: 29.5751, Val acc: 16.6667%, Best Val loss: 1.8000 Best Val acc: 16.67%
# Epoch 13/150, Train loss: 1.6164, Train acc: 37.5000%, Val loss: 9.6882, Val acc: 11.1111%, Best Val loss: 1.8000 Best Val acc: 16.67%
# Epoch 14/150, Train loss: 1.5557, Train acc: 40.2778%, Val loss: 17.5584, Val acc: 16.6667%, Best Val loss: 1.8000 Best Val acc: 16.67%
# Epoch 15/150, Train loss: 1.5912, Train acc: 30.5556%, Val loss: 11.9015, Val acc: 16.6667%, Best Val loss: 1.8000 Best Val acc: 16.67%
# Epoch 16/150, Train loss: 1.6334, Train acc: 27.7778%, Val loss: 6.7297, Val acc: 16.6667%, Best Val loss: 1.8000 Best Val acc: 16.67%
# Epoch 17/150, Train loss: 1.6295, Train acc: 31.9444%, Val loss: 12.3454, Val acc: 11.1111%, Best Val loss: 1.8000 Best Val acc: 16.67%
# Epoch 18/150, Train loss: 1.5899, Train acc: 34.7222%, Val loss: 5.8426, Val acc: 22.2222%, Best Val loss: 1.8000 Best Val acc: 22.22%
# Epoch 19/150, Train loss: 1.5084, Train acc: 40.2778%, Val loss: 4.1306, Val acc: 27.7778%, Best Val loss: 1.8000 Best Val acc: 27.78%
# Epoch 20/150, Train loss: 1.4546, Train acc: 41.6667%, Val loss: 2.4813, Val acc: 11.1111%, Best Val loss: 1.8000 Best Val acc: 27.78%
# Epoch 21/150, Train loss: 1.5740, Train acc: 43.0556%, Val loss: 1.7008, Val acc: 11.1111%, Best Val loss: 1.7008 Best Val acc: 27.78%
# Epoch 22/150, Train loss: 1.5268, Train acc: 37.5000%, Val loss: 1.5242, Val acc: 16.6667%, Best Val loss: 1.5242 Best Val acc: 27.78%
# Epoch 23/150, Train loss: 1.6067, Train acc: 33.3333%, Val loss: 1.5070, Val acc: 33.3333%, Best Val loss: 1.5070 Best Val acc: 33.33%
# Epoch 24/150, Train loss: 1.3566, Train acc: 54.1667%, Val loss: 1.5696, Val acc: 33.3333%, Best Val loss: 1.5070 Best Val acc: 33.33%
# Epoch 25/150, Train loss: 1.4339, Train acc: 48.6111%, Val loss: 1.4494, Val acc: 27.7778%, Best Val loss: 1.4494 Best Val acc: 33.33%
# Epoch 26/150, Train loss: 1.4409, Train acc: 38.8889%, Val loss: 1.4212, Val acc: 27.7778%, Best Val loss: 1.4212 Best Val acc: 33.33%
# Epoch 27/150, Train loss: 1.4005, Train acc: 44.4444%, Val loss: 1.4175, Val acc: 50.0000%, Best Val loss: 1.4175 Best Val acc: 50.00%
# Epoch 28/150, Train loss: 1.5819, Train acc: 31.9444%, Val loss: 1.2971, Val acc: 50.0000%, Best Val loss: 1.2971 Best Val acc: 50.00%
# Epoch 29/150, Train loss: 1.5920, Train acc: 40.2778%, Val loss: 1.4871, Val acc: 55.5556%, Best Val loss: 1.2971 Best Val acc: 55.56%
# Epoch 30/150, Train loss: 1.5156, Train acc: 40.2778%, Val loss: 1.4359, Val acc: 55.5556%, Best Val loss: 1.2971 Best Val acc: 55.56%
# Epoch 31/150, Train loss: 1.4601, Train acc: 40.2778%, Val loss: 1.3880, Val acc: 61.1111%, Best Val loss: 1.2971 Best Val acc: 61.11%
# Epoch 32/150, Train loss: 1.4911, Train acc: 47.2222%, Val loss: 1.2805, Val acc: 66.6667%, Best Val loss: 1.2805 Best Val acc: 66.67%
# Epoch 33/150, Train loss: 1.3317, Train acc: 48.6111%, Val loss: 1.2604, Val acc: 50.0000%, Best Val loss: 1.2604 Best Val acc: 66.67%
# Epoch 34/150, Train loss: 1.4700, Train acc: 47.2222%, Val loss: 1.3358, Val acc: 61.1111%, Best Val loss: 1.2604 Best Val acc: 66.67%
# Epoch 35/150, Train loss: 1.3576, Train acc: 45.8333%, Val loss: 1.4194, Val acc: 61.1111%, Best Val loss: 1.2604 Best Val acc: 66.67%
# Epoch 36/150, Train loss: 1.3859, Train acc: 44.4444%, Val loss: 1.4333, Val acc: 55.5556%, Best Val loss: 1.2604 Best Val acc: 66.67%
# Epoch 37/150, Train loss: 1.3606, Train acc: 48.6111%, Val loss: 1.3485, Val acc: 66.6667%, Best Val loss: 1.2604 Best Val acc: 66.67%
# Epoch 38/150, Train loss: 1.4734, Train acc: 47.2222%, Val loss: 1.2290, Val acc: 55.5556%, Best Val loss: 1.2290 Best Val acc: 66.67%
# Epoch 39/150, Train loss: 1.5295, Train acc: 38.8889%, Val loss: 1.3084, Val acc: 66.6667%, Best Val loss: 1.2290 Best Val acc: 66.67%
# Epoch 40/150, Train loss: 1.4065, Train acc: 44.4444%, Val loss: 1.3410, Val acc: 61.1111%, Best Val loss: 1.2290 Best Val acc: 66.67%
# Epoch 41/150, Train loss: 1.4538, Train acc: 45.8333%, Val loss: 1.2593, Val acc: 55.5556%, Best Val loss: 1.2290 Best Val acc: 66.67%
# Epoch 42/150, Train loss: 1.4345, Train acc: 51.3889%, Val loss: 1.3082, Val acc: 61.1111%, Best Val loss: 1.2290 Best Val acc: 66.67%
# Epoch 43/150, Train loss: 1.4563, Train acc: 40.2778%, Val loss: 1.4320, Val acc: 55.5556%, Best Val loss: 1.2290 Best Val acc: 66.67%
# Epoch 44/150, Train loss: 1.5897, Train acc: 34.7222%, Val loss: 1.3554, Val acc: 61.1111%, Best Val loss: 1.2290 Best Val acc: 66.67%
# Epoch 45/150, Train loss: 1.4073, Train acc: 50.0000%, Val loss: 1.4753, Val acc: 55.5556%, Best Val loss: 1.2290 Best Val acc: 66.67%
# Epoch 46/150, Train loss: 1.4531, Train acc: 43.0556%, Val loss: 1.3797, Val acc: 61.1111%, Best Val loss: 1.2290 Best Val acc: 66.67%
# Epoch 47/150, Train loss: 1.4608, Train acc: 41.6667%, Val loss: 1.2959, Val acc: 55.5556%, Best Val loss: 1.2290 Best Val acc: 66.67%
# Epoch 48/150, Train loss: 1.2872, Train acc: 55.5556%, Val loss: 1.3079, Val acc: 55.5556%, Best Val loss: 1.2290 Best Val acc: 66.67%
# Epoch 49/150, Train loss: 1.3568, Train acc: 45.8333%, Val loss: 1.3425, Val acc: 44.4444%, Best Val loss: 1.2290 Best Val acc: 66.67%
# Epoch 50/150, Train loss: 1.5062, Train acc: 47.2222%, Val loss: 1.3370, Val acc: 50.0000%, Best Val loss: 1.2290 Best Val acc: 66.67%
# Epoch 51/150, Train loss: 1.3927, Train acc: 48.6111%, Val loss: 1.4289, Val acc: 44.4444%, Best Val loss: 1.2290 Best Val acc: 66.67%
# Epoch 52/150, Train loss: 1.4573, Train acc: 40.2778%, Val loss: 1.4993, Val acc: 38.8889%, Best Val loss: 1.2290 Best Val acc: 66.67%
# Epoch 53/150, Train loss: 1.4514, Train acc: 43.0556%, Val loss: 1.3870, Val acc: 55.5556%, Best Val loss: 1.2290 Best Val acc: 66.67%
# Epoch 54/150, Train loss: 1.3206, Train acc: 40.2778%, Val loss: 1.1833, Val acc: 50.0000%, Best Val loss: 1.1833 Best Val acc: 66.67%
# Epoch 55/150, Train loss: 1.3499, Train acc: 45.8333%, Val loss: 1.1780, Val acc: 50.0000%, Best Val loss: 1.1780 Best Val acc: 66.67%
# Epoch 56/150, Train loss: 1.3460, Train acc: 47.2222%, Val loss: 1.3137, Val acc: 44.4444%, Best Val loss: 1.1780 Best Val acc: 66.67%
# Epoch 57/150, Train loss: 1.4165, Train acc: 37.5000%, Val loss: 1.3290, Val acc: 61.1111%, Best Val loss: 1.1780 Best Val acc: 66.67%
# Epoch 58/150, Train loss: 1.4667, Train acc: 33.3333%, Val loss: 1.2113, Val acc: 72.2222%, Best Val loss: 1.1780 Best Val acc: 72.22%
# Epoch 59/150, Train loss: 1.4349, Train acc: 43.0556%, Val loss: 1.1072, Val acc: 61.1111%, Best Val loss: 1.1072 Best Val acc: 72.22%
# Epoch 60/150, Train loss: 1.4370, Train acc: 43.0556%, Val loss: 1.1651, Val acc: 66.6667%, Best Val loss: 1.1072 Best Val acc: 72.22%
# Epoch 61/150, Train loss: 1.5326, Train acc: 41.6667%, Val loss: 1.0787, Val acc: 66.6667%, Best Val loss: 1.0787 Best Val acc: 72.22%
# Epoch 62/150, Train loss: 1.3898, Train acc: 45.8333%, Val loss: 1.1205, Val acc: 61.1111%, Best Val loss: 1.0787 Best Val acc: 72.22%
# Epoch 63/150, Train loss: 1.3716, Train acc: 38.8889%, Val loss: 1.2711, Val acc: 66.6667%, Best Val loss: 1.0787 Best Val acc: 72.22%
# Epoch 64/150, Train loss: 1.3395, Train acc: 41.6667%, Val loss: 1.2555, Val acc: 66.6667%, Best Val loss: 1.0787 Best Val acc: 72.22%
# Epoch 65/150, Train loss: 1.4579, Train acc: 44.4444%, Val loss: 1.2300, Val acc: 61.1111%, Best Val loss: 1.0787 Best Val acc: 72.22%
# Epoch 66/150, Train loss: 1.3105, Train acc: 43.0556%, Val loss: 1.1550, Val acc: 61.1111%, Best Val loss: 1.0787 Best Val acc: 72.22%
# Epoch 67/150, Train loss: 1.3521, Train acc: 41.6667%, Val loss: 1.1735, Val acc: 61.1111%, Best Val loss: 1.0787 Best Val acc: 72.22%
# Epoch 68/150, Train loss: 1.3529, Train acc: 48.6111%, Val loss: 1.1166, Val acc: 55.5556%, Best Val loss: 1.0787 Best Val acc: 72.22%
# Epoch 69/150, Train loss: 1.3679, Train acc: 47.2222%, Val loss: 0.9590, Val acc: 77.7778%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 70/150, Train loss: 1.4112, Train acc: 52.7778%, Val loss: 0.9677, Val acc: 72.2222%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 71/150, Train loss: 1.3629, Train acc: 51.3889%, Val loss: 1.0288, Val acc: 55.5556%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 72/150, Train loss: 1.4274, Train acc: 48.6111%, Val loss: 1.1010, Val acc: 44.4444%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 73/150, Train loss: 1.3729, Train acc: 55.5556%, Val loss: 1.0180, Val acc: 55.5556%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 74/150, Train loss: 1.3710, Train acc: 48.6111%, Val loss: 1.0984, Val acc: 55.5556%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 75/150, Train loss: 1.3537, Train acc: 50.0000%, Val loss: 1.1068, Val acc: 66.6667%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 76/150, Train loss: 1.3183, Train acc: 56.9444%, Val loss: 1.0404, Val acc: 72.2222%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 77/150, Train loss: 1.4117, Train acc: 45.8333%, Val loss: 1.2764, Val acc: 50.0000%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 78/150, Train loss: 1.3988, Train acc: 50.0000%, Val loss: 1.3207, Val acc: 50.0000%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 79/150, Train loss: 1.3312, Train acc: 50.0000%, Val loss: 1.1438, Val acc: 61.1111%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 80/150, Train loss: 1.3575, Train acc: 48.6111%, Val loss: 1.1842, Val acc: 61.1111%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 81/150, Train loss: 1.2034, Train acc: 48.6111%, Val loss: 1.0219, Val acc: 55.5556%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 82/150, Train loss: 1.3055, Train acc: 47.2222%, Val loss: 1.0764, Val acc: 61.1111%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 83/150, Train loss: 1.3487, Train acc: 54.1667%, Val loss: 1.2618, Val acc: 72.2222%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 84/150, Train loss: 1.4032, Train acc: 43.0556%, Val loss: 1.3540, Val acc: 66.6667%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 85/150, Train loss: 1.3002, Train acc: 45.8333%, Val loss: 1.2980, Val acc: 61.1111%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 86/150, Train loss: 1.2938, Train acc: 48.6111%, Val loss: 1.2635, Val acc: 50.0000%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 87/150, Train loss: 1.2866, Train acc: 50.0000%, Val loss: 1.1993, Val acc: 50.0000%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 88/150, Train loss: 1.3041, Train acc: 54.1667%, Val loss: 1.1209, Val acc: 61.1111%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 89/150, Train loss: 1.3726, Train acc: 44.4444%, Val loss: 1.0624, Val acc: 55.5556%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 90/150, Train loss: 1.2884, Train acc: 54.1667%, Val loss: 1.0433, Val acc: 66.6667%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 91/150, Train loss: 1.4607, Train acc: 48.6111%, Val loss: 1.1431, Val acc: 38.8889%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 92/150, Train loss: 1.2288, Train acc: 59.7222%, Val loss: 1.2316, Val acc: 55.5556%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 93/150, Train loss: 1.2143, Train acc: 47.2222%, Val loss: 1.2620, Val acc: 61.1111%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 94/150, Train loss: 1.4078, Train acc: 50.0000%, Val loss: 1.2112, Val acc: 44.4444%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 95/150, Train loss: 1.4211, Train acc: 44.4444%, Val loss: 1.2103, Val acc: 50.0000%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 96/150, Train loss: 1.2944, Train acc: 51.3889%, Val loss: 1.1117, Val acc: 44.4444%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 97/150, Train loss: 1.2936, Train acc: 47.2222%, Val loss: 1.1832, Val acc: 66.6667%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 98/150, Train loss: 1.2332, Train acc: 52.7778%, Val loss: 1.3239, Val acc: 66.6667%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 99/150, Train loss: 1.3574, Train acc: 44.4444%, Val loss: 1.3706, Val acc: 55.5556%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 100/150, Train loss: 1.2536, Train acc: 51.3889%, Val loss: 1.3150, Val acc: 55.5556%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 101/150, Train loss: 1.4049, Train acc: 44.4444%, Val loss: 1.1845, Val acc: 44.4444%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 102/150, Train loss: 1.3344, Train acc: 48.6111%, Val loss: 1.0225, Val acc: 66.6667%, Best Val loss: 0.9590 Best Val acc: 77.78%
# Epoch 103/150, Train loss: 1.4039, Train acc: 47.2222%, Val loss: 0.9544, Val acc: 66.6667%, Best Val loss: 0.9544 Best Val acc: 77.78%
# Epoch 104/150, Train loss: 1.3231, Train acc: 50.0000%, Val loss: 1.0943, Val acc: 61.1111%, Best Val loss: 0.9544 Best Val acc: 77.78%
# Epoch 105/150, Train loss: 1.3040, Train acc: 51.3889%, Val loss: 1.1531, Val acc: 66.6667%, Best Val loss: 0.9544 Best Val acc: 77.78%
# Epoch 106/150, Train loss: 1.1770, Train acc: 59.7222%, Val loss: 1.1251, Val acc: 61.1111%, Best Val loss: 0.9544 Best Val acc: 77.78%
# Epoch 107/150, Train loss: 1.3009, Train acc: 47.2222%, Val loss: 1.2880, Val acc: 55.5556%, Best Val loss: 0.9544 Best Val acc: 77.78%
# Epoch 108/150, Train loss: 1.3202, Train acc: 45.8333%, Val loss: 1.3051, Val acc: 55.5556%, Best Val loss: 0.9544 Best Val acc: 77.78%
# Epoch 109/150, Train loss: 1.1572, Train acc: 52.7778%, Val loss: 1.2333, Val acc: 61.1111%, Best Val loss: 0.9544 Best Val acc: 77.78%
# Epoch 110/150, Train loss: 1.3113, Train acc: 54.1667%, Val loss: 1.1047, Val acc: 61.1111%, Best Val loss: 0.9544 Best Val acc: 77.78%
# Epoch 111/150, Train loss: 1.2769, Train acc: 56.9444%, Val loss: 1.0714, Val acc: 50.0000%, Best Val loss: 0.9544 Best Val acc: 77.78%
# Epoch 112/150, Train loss: 1.2061, Train acc: 59.7222%, Val loss: 1.0099, Val acc: 55.5556%, Best Val loss: 0.9544 Best Val acc: 77.78%
# Epoch 113/150, Train loss: 1.1589, Train acc: 54.1667%, Val loss: 1.0917, Val acc: 55.5556%, Best Val loss: 0.9544 Best Val acc: 77.78%
# Epoch 114/150, Train loss: 1.3428, Train acc: 50.0000%, Val loss: 1.0518, Val acc: 72.2222%, Best Val loss: 0.9544 Best Val acc: 77.78%
# Epoch 115/150, Train loss: 1.2073, Train acc: 54.1667%, Val loss: 1.0379, Val acc: 61.1111%, Best Val loss: 0.9544 Best Val acc: 77.78%
# Epoch 116/150, Train loss: 1.2438, Train acc: 52.7778%, Val loss: 0.9737, Val acc: 61.1111%, Best Val loss: 0.9544 Best Val acc: 77.78%
# Epoch 117/150, Train loss: 1.2781, Train acc: 54.1667%, Val loss: 0.9729, Val acc: 66.6667%, Best Val loss: 0.9544 Best Val acc: 77.78%
# Epoch 118/150, Train loss: 1.3428, Train acc: 47.2222%, Val loss: 1.0983, Val acc: 66.6667%, Best Val loss: 0.9544 Best Val acc: 77.78%
# Epoch 119/150, Train loss: 1.2858, Train acc: 48.6111%, Val loss: 1.0921, Val acc: 66.6667%, Best Val loss: 0.9544 Best Val acc: 77.78%
# Epoch 120/150, Train loss: 1.3570, Train acc: 54.1667%, Val loss: 0.9359, Val acc: 77.7778%, Best Val loss: 0.9359 Best Val acc: 77.78%
# Epoch 121/150, Train loss: 1.2351, Train acc: 48.6111%, Val loss: 0.9506, Val acc: 72.2222%, Best Val loss: 0.9359 Best Val acc: 77.78%
# Epoch 122/150, Train loss: 1.2135, Train acc: 55.5556%, Val loss: 0.9918, Val acc: 66.6667%, Best Val loss: 0.9359 Best Val acc: 77.78%
# Epoch 123/150, Train loss: 1.3822, Train acc: 38.8889%, Val loss: 1.0395, Val acc: 61.1111%, Best Val loss: 0.9359 Best Val acc: 77.78%
# Epoch 124/150, Train loss: 1.3469, Train acc: 54.1667%, Val loss: 0.9128, Val acc: 72.2222%, Best Val loss: 0.9128 Best Val acc: 77.78%
# Epoch 125/150, Train loss: 1.2433, Train acc: 48.6111%, Val loss: 1.1051, Val acc: 61.1111%, Best Val loss: 0.9128 Best Val acc: 77.78%
# Epoch 126/150, Train loss: 1.0741, Train acc: 61.1111%, Val loss: 0.9172, Val acc: 83.3333%, Best Val loss: 0.9128 Best Val acc: 83.33%
# Epoch 127/150, Train loss: 1.4397, Train acc: 43.0556%, Val loss: 0.9600, Val acc: 55.5556%, Best Val loss: 0.9128 Best Val acc: 83.33%
# Epoch 128/150, Train loss: 1.2139, Train acc: 50.0000%, Val loss: 1.0846, Val acc: 61.1111%, Best Val loss: 0.9128 Best Val acc: 83.33%
# Epoch 129/150, Train loss: 1.2763, Train acc: 52.7778%, Val loss: 1.1236, Val acc: 72.2222%, Best Val loss: 0.9128 Best Val acc: 83.33%
# Epoch 130/150, Train loss: 1.2424, Train acc: 54.1667%, Val loss: 1.1737, Val acc: 61.1111%, Best Val loss: 0.9128 Best Val acc: 83.33%
# Epoch 131/150, Train loss: 1.3021, Train acc: 50.0000%, Val loss: 1.0878, Val acc: 55.5556%, Best Val loss: 0.9128 Best Val acc: 83.33%
# Epoch 132/150, Train loss: 1.1922, Train acc: 59.7222%, Val loss: 1.1568, Val acc: 55.5556%, Best Val loss: 0.9128 Best Val acc: 83.33%
# Epoch 133/150, Train loss: 1.1864, Train acc: 45.8333%, Val loss: 1.1286, Val acc: 66.6667%, Best Val loss: 0.9128 Best Val acc: 83.33%
# Epoch 134/150, Train loss: 1.2084, Train acc: 55.5556%, Val loss: 1.2229, Val acc: 44.4444%, Best Val loss: 0.9128 Best Val acc: 83.33%
# Epoch 135/150, Train loss: 1.2764, Train acc: 55.5556%, Val loss: 1.0847, Val acc: 61.1111%, Best Val loss: 0.9128 Best Val acc: 83.33%
# Epoch 136/150, Train loss: 1.1867, Train acc: 59.7222%, Val loss: 1.0687, Val acc: 61.1111%, Best Val loss: 0.9128 Best Val acc: 83.33%
# Epoch 137/150, Train loss: 1.1774, Train acc: 55.5556%, Val loss: 1.1173, Val acc: 61.1111%, Best Val loss: 0.9128 Best Val acc: 83.33%
# Epoch 138/150, Train loss: 1.2425, Train acc: 50.0000%, Val loss: 1.0293, Val acc: 66.6667%, Best Val loss: 0.9128 Best Val acc: 83.33%
# Epoch 139/150, Train loss: 1.2689, Train acc: 52.7778%, Val loss: 1.1638, Val acc: 50.0000%, Best Val loss: 0.9128 Best Val acc: 83.33%
# Epoch 140/150, Train loss: 1.1531, Train acc: 56.9444%, Val loss: 1.1512, Val acc: 55.5556%, Best Val loss: 0.9128 Best Val acc: 83.33%
# Epoch 141/150, Train loss: 1.2772, Train acc: 52.7778%, Val loss: 1.1410, Val acc: 61.1111%, Best Val loss: 0.9128 Best Val acc: 83.33%
# Epoch 142/150, Train loss: 1.4115, Train acc: 43.0556%, Val loss: 0.9709, Val acc: 66.6667%, Best Val loss: 0.9128 Best Val acc: 83.33%
# Epoch 143/150, Train loss: 1.3417, Train acc: 50.0000%, Val loss: 0.9274, Val acc: 72.2222%, Best Val loss: 0.9128 Best Val acc: 83.33%
# Epoch 144/150, Train loss: 1.1981, Train acc: 58.3333%, Val loss: 1.0260, Val acc: 55.5556%, Best Val loss: 0.9128 Best Val acc: 83.33%
# Epoch 145/150, Train loss: 1.1562, Train acc: 61.1111%, Val loss: 0.9265, Val acc: 72.2222%, Best Val loss: 0.9128 Best Val acc: 83.33%
# Epoch 146/150, Train loss: 1.3827, Train acc: 47.2222%, Val loss: 1.0617, Val acc: 72.2222%, Best Val loss: 0.9128 Best Val acc: 83.33%
# Epoch 147/150, Train loss: 1.1941, Train acc: 55.5556%, Val loss: 1.0676, Val acc: 61.1111%, Best Val loss: 0.9128 Best Val acc: 83.33%
# Epoch 148/150, Train loss: 1.3965, Train acc: 43.0556%, Val loss: 0.9711, Val acc: 72.2222%, Best Val loss: 0.9128 Best Val acc: 83.33%
# Epoch 149/150, Train loss: 1.2782, Train acc: 48.6111%, Val loss: 0.9971, Val acc: 61.1111%, Best Val loss: 0.9128 Best Val acc: 83.33%
# Epoch 150/150, Train loss: 1.1632, Train acc: 55.5556%, Val loss: 0.9540, Val acc: 50.0000%, Best Val loss: 0.9128 Best Val acc: 83.33%

# %% [markdown]
# ### Visualizing model performance

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

# Plotting training and validation accuracy
ax[0].plot(train_accuracies)
ax[0].plot(val_accuracies)
ax[0].set_title('Model Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(['Train', 'Val'])

# Plotting training and validation loss
ax[1].plot(train_losses)
ax[1].plot(val_losses)
ax[1].set_title('Model Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(['Train', 'Val'])

plt.show()

# %% [markdown]
# ## D. Evaluating Your Trained Model

# %% [markdown]
# ### Load Trained Model and Evaluate

# %%
# Load the trained weights
model.load_state_dict(torch.load('model_classification.pth'))

# Set the model to evaluation mode
model.eval()

test_correct = 0
test_total = 0

with torch.no_grad():
    for images, labels in val_loader:

        images = images.cuda()
        images = (images) / 255.

        labels = labels.cuda()
        labels = labels.long()

        outputs = model(images)

        predicted = outputs.argmax(-1)
        print(predicted)
        print(labels)
        test_correct += (predicted == labels).sum().item()
        test_total += labels.size(0)

print(f'Test accuracy is {100. * test_correct / test_total}%')
# Out:
# tensor([0, 2, 0, 1, 3, 1, 2, 2, 2, 3, 3, 3, 4, 4, 4, 0], device='cuda:0')
# tensor([0, 0, 0, 1, 1, 1, 2, 2, 2, 3, 3, 3, 4, 4, 4, 5], device='cuda:0')
# tensor([5, 5], device='cuda:0')
# tensor([5, 5], device='cuda:0')
# Test accuracy is 83.33333333333333%
